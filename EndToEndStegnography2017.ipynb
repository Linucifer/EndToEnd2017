# %% [markdown]
# ## **host_channels**=3; **guest_channels**=1; **epoch**=50; **batch_size**=64; **encoder_weight**=1; **decoder_weight**=1; **learning_rate**=1e-4

# %%
# !python /content/drive/MyDrive/MyModels/End_to_end_Stegnography_2017/train.py
# Out:
# Files already downloaded and verified
# Running device is cuda
# Train Epoch: 0: 100% 157/157 [00:35<00:00,  4.39it/s]
# Val Epoch 0: 100% 157/157 [00:04<00:00, 34.46it/s]
# Epoch 0 train_loss: 0.517533841975935
# Epoch 0 val_loss: 0.7716596183503509
# Validation loss decreased inf --> 0.7716596183503509
# Save model successfully! path: /content/drive/MyDrive/MyModels/End_to_end_Stegnography_2017/steg_net_host3_guest1_epochNum50_batchSize128_lr0.0001_encoderWeight1_decoderWeight1.pth
# Train Epoch: 1: 100% 157/157 [00:35<00:00,  4.48it/s]
# Val Epoch 1: 100% 157/157 [00:04<00:00, 36.04it/s]
# Epoch 1 train_loss: 0.33958693807292134
# Epoch 1 val_loss: 0.5960548626389474
# Validation loss decreased 0.7716596183503509 --> 0.5960548626389474
# Save model successfully! path: /content/drive/MyDrive/MyModels/End_to_end_Stegnography_2017/steg_net_host3_guest1_epochNum50_batchSize128_lr0.0001_encoderWeight1_decoderWeight1.pth
# Train Epoch: 2: 100% 157/157 [00:35<00:00,  4.43it/s]
# ...
